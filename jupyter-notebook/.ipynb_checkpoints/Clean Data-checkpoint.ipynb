# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", None)

# %%
def create_df(year):
    return pd.read_csv('../Data/ACO.SSP.PUF.Y{}.csv'.format(year), index_col=0)

def change_to_date(df, col_name):
    df[col_name] = pd.to_datetime(df[col_name])

def generate_col_name():
    col_names = []
    for num in list:
        col_names.append('ACO{}'.format(num))
    return col_names

def remove_commas(df, col_name):
    df[col_name] = df[col_name].str.replace(",","")

def change_to_num(df, col_name):
    df[col_name] = pd.to_numeric(df[col_name], errors="coerce")

# %%
df16 = create_df(2016)

change_to_date(df16, 'Initial_Start_Date')
change_to_date(df16, 'Current_Start_Date')
list = [1,2,3,4,5,6,7,13,14,15,16,17,18,19,20,21,27,28,30,31,33,34,39,40,41,42]

col_names = generate_col_name()

for col in col_names:
    remove_commas(df16, col)
    change_to_num(df16, col)

remove_commas(df16, 'DM_Comp')
change_to_num(df16,'DM_Comp')
    
df16.ACO40
# Out:
# ACO_Num
# A67373     8.33
# A38665     0.00
# A76261     3.85
# A38596     2.94
# A60892     3.13
# A58483     0.00
# A61599     0.00
# A46707     0.00
# A28708     9.09
# A04423     1.45
# A85439    15.00
# A15929     6.38
# A86333     3.13
# A76034     0.00
# A05657     9.09
# A53334      NaN
# A51279     6.25
# A34178     0.00
# A24802     0.00
# A01714    13.77
# A33196    14.29
# A05273     0.00
# A65596     7.06
# A27119     0.00
# A99401     2.38
# A92107     6.98
# A18256     0.00
# A70756     2.78
# A55129     0.00
# A09897     0.00
# A67345    21.43
# A64629     0.00
# A82596     0.00
# A38110     0.00
# A44053    13.33
# A87823    45.45
# A89093     2.63
# A65526     9.52
# A40874     3.03
# A01334     0.00
# A52780     2.63
# A91882      NaN
# A05872     0.00
# A46043    12.50
# A10273     8.33
# A70411    17.24
# A12621     9.09
# A91115    23.08
# A58588     0.00
# A46075     6.25
# A52797     0.00
# A66733     0.00
# A98813    25.93
# A43014     6.67
# A42388     0.00
# A40070     6.90
# A26898     8.33
# A79251     9.09
# A62480     5.26
# A71489     0.00
# A78144    13.19
# A64316     3.03
# A95753     9.80
# A09762    25.00
# A31344     6.52
# A10764     0.00
# A59256     3.85
# A13682     0.00
# A05247    12.96
# A14573    17.39
# A55185     9.68
# A75525      NaN
# A33458     7.69
# A21965    23.08
# A03682     0.00
# A45848     0.00
# A74604     0.00
# A97609     8.33
# A00755     0.00
# A23779     0.00
# A60499     0.00
# A30070     6.67
# A73700     0.00
# A94529     0.00
# A32235     7.14
# A19579    10.71
# A00843     8.47
# A45761     0.00
# A80267     3.57
# A01645     5.71
# A69939     0.00
# A99470     0.00
# A71510     0.00
# A21778     1.52
# A95164     0.00
# A73727     9.09
# A83092    11.11
# A32930     4.35
# A96588     0.00
# A34796     0.00
# A28700    10.53
# A42036     2.78
# A69364     0.00
# A02541    15.38
# A12533     0.00
# A45364     0.00
# A38167     0.00
# A73340      NaN
# A81035    10.00
# A94621    10.53
# A70850     2.50
# A91256     0.00
# A72294    20.00
# A54859     5.71
# A84785     7.69
# A82661     8.33
# A76577     9.09
# A39327    12.50
# A86799     2.78
# A48354     4.65
# A10419     0.00
# A25914     4.17
# A02472     8.70
# A07870    11.76
# A43641    37.93
# A51491     1.96
# A05696      NaN
# A54437     0.00
# A00934    12.31
# A22020     0.00
# A78337     0.00
# A42284    13.04
# A87771     0.00
# A22066     6.00
# A92374    25.00
# A34443    41.94
# A11103     0.00
# A67733     0.00
# A19446     0.00
# A64801     0.00
# A76576    16.13
# A94912    13.04
# A64742     3.45
# A18259      NaN
# A17182     0.00
# A31015     7.14
# A65320     5.26
# A16779    12.99
# A41997      NaN
# A50496     3.23
# A80939    12.50
# A55446    11.76
# A66745     8.33
# A07425     0.00
# A74161     7.69
# A29052    25.00
# A50010     0.00
# A63217      NaN
# A45396     3.09
# A28160      NaN
# A65270     0.00
# A78634     6.67
# A90093     0.00
# A19855     0.00
# A69078      NaN
# A07527    13.64
# A80995     5.71
# A78902     9.09
# A97104    24.00
# A46189    33.33
# A60540     0.00
# A79092     0.00
# A54247     0.00
# A52095     0.00
# A55910    21.43
# A29818    10.67
# A81860    20.00
# A74238    14.29
# A13467    20.00
# A69881      NaN
# A53129     0.00
# A39818     0.00
# A60310     0.00
# A26254    35.29
# A39151     2.50
# A12732     6.00
# A82427     4.76
# A02094    13.75
# A89091     5.56
# A02865     9.76
# A33172    67.86
# A34484     0.00
# A58599     0.00
# A10440     0.00
# A17931     0.00
# A80878     0.00
# A07386     0.00
# A36039     8.33
# A27492     4.48
# A76825     0.00
# A40650     0.00
# A22925     0.00
# A47465     0.00
# A01307     0.00
# A29971    40.00
# A25380     7.69
# A81718     0.00
# A40225     2.22
# A07004     0.00
# A17106      NaN
# A15030     0.00
# A73981    11.11
# A90742     0.00
# A81453     0.00
# A87886     4.76
# A03202     0.00
# A38185     0.00
# A39529     0.00
# A79168     0.00
# A02128     5.88
# A49262     0.00
# A36517     0.00
# A46995    10.71
# A39975    13.89
# A23908     7.14
# A72235     0.00
# A07620    11.11
# A06665     0.00
# A68137     5.88
# A74254     0.00
# A82420    22.22
# A60743     0.00
# A17898     9.76
# A86442     0.00
# A70064     0.00
# A02854     0.00
# A08611      NaN
# A23786    19.23
# A38301     0.00
# A71307     0.00
# A23727     0.00
# A43717     0.00
# A18812     8.33
# A91435     9.09
# A08181     5.88
# A24804     0.00
# A67365     0.00
# A49168    13.33
# A91307     5.56
# A95248      NaN
# A11353     0.00
# A05950     7.32
# A25744      NaN
# A74448     9.76
# A73551     2.74
# A17964    11.90
# A49534     0.00
# A72677     0.00
# A73256     5.56
# A83232     0.00
# A07732     0.00
# A65633    40.00
# A74976    13.04
# A88553     6.82
# A60323     5.00
# A59161     8.33
# A34814     0.00
# A07334     0.00
# A29195    27.27
# A60023     0.00
# A81088    17.65
# A23513     0.00
# A86004      NaN
# A95812      NaN
# A92234     0.00
# A60552     0.00
# A59192      NaN
# A83956    11.76
# A74449     0.00
# A51793     0.00
# A39107     5.26
# A25701     0.00
# A24605    15.07
# A14417     1.96
# A71487    14.29
# A34708    33.33
# A75625     0.00
# A17606     0.00
# A47392      NaN
# A23437     0.00
# A81076     0.00
# A87355     0.00
# A85343      NaN
# A96888     0.00
# A33146     0.00
# A35510     0.00
# A60506     4.76
# A63260     7.14
# A86344     0.00
# A24144     4.55
# A32730      NaN
# A87299     0.00
# A66096     0.00
# A07433     0.00
# A55003      NaN
# A57266    11.76
# A03716     8.00
# A47655     8.00
# A76834      NaN
# A02219    15.38
# A94900     0.00
# A79410     0.00
# A48017     0.00
# A98243      NaN
# A50281     0.00
# A71749    40.00
# A47336     0.00
# A07769     6.25
# A69405     0.00
# A05496     0.00
# A80674      NaN
# A42910    14.29
# A15196     0.00
# A93114     0.00
# A79694     0.00
# A44499     0.00
# A48401     0.00
# A93261    20.00
# A25097     1.82
# A47101     0.00
# A29177    14.29
# A23015     3.85
# A54062     0.00
# A20488     0.00
# A71640      NaN
# A95141    20.00
# A66885      NaN
# A99459     0.00
# A70007     0.00
# A69673     0.00
# A72971      NaN
# A20168    55.88
# A96978      NaN
# A12439     0.00
# A54464      NaN
# A61540    57.14
# A53342     0.00
# A84924     0.00
# A24077     0.00
# A91712     5.00
# A33500    19.35
# A71684    10.00
# A50347     0.00
# A78429      NaN
# A65119     7.69
# A09392     0.00
# A03133     7.14
# A64090      NaN
# A99911     0.00
# A90925     8.50
# A54198      NaN
# A58031    10.00
# A59816     0.00
# A38977     0.00
# A61487     0.00
# A84870    25.00
# A97980     0.00
# A43071      NaN
# A75055     0.00
# A45565     3.85
# A17748     0.00
# A69337     5.63
# A41540     0.00
# A55037     0.00
# A85619      NaN
# A80689    30.77
# A33509     0.00
# A55033     8.57
# A46443     3.57
# A60541     2.33
# A38567     3.03
# A27169     0.00
# A53441    12.28
# A94144      NaN
# A17196     0.00
# A18013     9.09
# A79194    17.39
# A84144     0.00
# A47151      NaN
# A66931     0.00
# A10162     0.00
# A33934     0.00
# A20938    50.00
# A02551    23.81
# A12017     0.00
# A57853     5.00
# A40908     0.00
# A12141      NaN
# A56403      NaN
# A06512     0.00
# A93592     0.00
# A27912     0.00
# A38726     0.00
# A22038     0.00
# A26666     7.69
# A82552    60.00
# A20392     0.00
# A50190    10.53
# A68005      NaN
# A47940     0.00
# A28055    16.67
# A19490     0.00
# A87238    10.00
# A53560    12.50
# A23652     0.00
# A53506     0.00
# A48272     0.00
# A20311     0.00
# A57563     6.25
# A76184     8.00
# A08783     0.00
# A16388     1.32
# A76503     0.00
# A28163     0.00
# A26399     0.00
# A74494    25.00
# A69266     6.25
# A17421     2.04
# A19727      NaN
# A03907    11.11
# A78012     0.00
# A13888     0.00
# Name: ACO40, dtype: float64

# %%
df15 = create_df(2015)

for col in df15.columns[6:38]:
    remove_commas(df15, col)
    change_to_num(df15, col)
    
change_to_date(df15, 'Start_Date')

df15.dtypes
# Out:
# ACO_Name                               object
# ACO_State                              object
# Start_Date                     datetime64[ns]
# Track1                                  int64
# Track2                                  int64
# Adv_Pay                                 int64
# N_AB                                    int64
# Sav_rate                              float64
# MinSavPerc                            float64
# BnchmkMinExp                            int64
# GenSaveLoss                             int64
# EarnSaveLoss                            int64
# QualScore                             float64
# UpdatedBnchmk                           int64
# HistBnchmk                              int64
# ABtotBnchmk                             int64
# ABtotExp                                int64
# Adv_Pay_Amt                           float64
# Adv_Pay_Recoup                        float64
# QualPerfShare                         float64
# FinalShareRate                        float64
# Per_Capita_Exp_ALL_ESRD_BY1             int64
# Per_Capita_Exp_ALL_DIS_BY1              int64
# Per_Capita_Exp_ALL_AGDU_BY1             int64
# Per_Capita_Exp_ALL_AGND_BY1             int64
# Per_Capita_Exp_ALL_ESRD_BY2             int64
# Per_Capita_Exp_ALL_DIS_BY2              int64
# Per_Capita_Exp_ALL_AGDU_BY2             int64
# Per_Capita_Exp_ALL_AGND_BY2             int64
# Per_Capita_Exp_ALL_ESRD_BY3             int64
# Per_Capita_Exp_ALL_DIS_BY3              int64
# Per_Capita_Exp_ALL_AGDU_BY3             int64
# Per_Capita_Exp_ALL_AGND_BY3             int64
# Per_Capita_Exp_ALL_ESRD_PY              int64
# Per_Capita_Exp_ALL_DIS_PY               int64
# Per_Capita_Exp_ALL_AGDU_PY              int64
# Per_Capita_Exp_ALL_AGND_PY              int64
# Per_Capita_Exp_TOTAL_PY                 int64
# CMS_HCC_RiskScore_ESRD_BY1            float64
# CMS_HCC_RiskScore_DIS_BY1             float64
# CMS_HCC_RiskScore_AGDU_BY1            float64
# CMS_HCC_RiskScore_AGND_BY1            float64
# CMS_HCC_RiskScore_ESRD_BY2            float64
# CMS_HCC_RiskScore_DIS_BY2             float64
# CMS_HCC_RiskScore_AGDU_BY2            float64
# CMS_HCC_RiskScore_AGND_BY2            float64
# CMS_HCC_RiskScore_ESRD_BY3            float64
# CMS_HCC_RiskScore_DIS_BY3             float64
# CMS_HCC_RiskScore_AGDU_BY3            float64
# CMS_HCC_RiskScore_AGND_BY3            float64
# CMS_HCC_RiskScore_ESRD_PY             float64
# CMS_HCC_RiskScore_DIS_PY              float64
# CMS_HCC_RiskScore_AGDU_PY             float64
# CMS_HCC_RiskScore_AGND_PY             float64
# N_AB_Year_ESRD_BY3                      int64
# N_AB_Year_DIS_BY3                       int64
# N_AB_Year_AGED_Dual_BY3                 int64
# N_AB_Year_AGED_NonDual_BY3              int64
# N_AB_Year_PY                            int64
# N_AB_Year_ESRD_PY                       int64
# N_AB_Year_DIS_PY                        int64
# N_AB_Year_AGED_Dual_PY                  int64
# N_AB_Year_AGED_NonDual_PY               int64
# N_Ben_Age_0_64                          int64
# N_Ben_Age_65_74                         int64
# N_Ben_Age_75_84                         int64
# N_Ben_Age_85plus                        int64
# N_Ben_Female                            int64
# N_Ben_Male                              int64
# N_Ben_Race_White                        int64
# N_Ben_Race_Black                        int64
# N_Ben_Race_Asian                        int64
# N_Ben_Race_Hisp                         int64
# N_Ben_Race_Native                       int64
# N_Ben_Race_Other                        int64
# CapAnn_INP_All                          int64
# CapAnn_INP_S_trm                        int64
# CapAnn_INP_L_trm                        int64
# CapAnn_INP_Rehab                        int64
# CapAnn_INP_Psych                        int64
# CapAnn_HSP                              int64
# CapAnn_SNF                              int64
# CapAnn_INP_Other                        int64
# CapAnn_OPD                              int64
# CapAnn_PB                               int64
# CapAnn_AmbPay                           int64
# CapAnn_HHA                              int64
# CapAnn_DME                              int64
# ADM                                     int64
# ADM_S_Trm                               int64
# ADM_L_Trm                               int64
# ADM_Rehab                               int64
# ADM_Psych                               int64
# chf_adm                                 int64
# copd_adm                                int64
# pneu_adm                                int64
# readm_Rate_1000                         int64
# prov_Rate_1000                          int64
# P_SNF_ADM                               int64
# P_EDV_Vis                               int64
# P_EDV_Vis_HOSP                          int64
# P_CT_VIS                                int64
# P_MRI_VIS                               int64
# P_EM_Total                              int64
# P_EM_PCP_Vis                            int64
# P_EM_SP_Vis                             int64
# P_Nurse_Vis                             int64
# P_FQHC_RHC_Vis                          int64
# N_CAH                                   int64
# N_FQHC                                  int64
# N_RHC                                   int64
# N_ETA                                   int64
# N_Fac_Other                             int64
# N_PCP                                   int64
# N_Spec                                  int64
# N_NP                                    int64
# N_PA                                    int64
# N_CNS                                   int64
# dtype: object

# %%
df14 = create_df(2014)

change_to_date(df14,'Start_Date')
change_to_num(df14, 'QualScore')

df14.dtypes
# Out:
# ACO_Name                               object
# ACO_State                              object
# Start_Date                     datetime64[ns]
# Track1                                  int64
# Track2                                  int64
# Adv_Pay                                 int64
# N_AB                                    int64
# Sav_rate                              float64
# MinSavPerc                            float64
# BnchmkMinExp                            int64
# GenSaveLoss                             int64
# EarnSaveLoss                            int64
# QualScore                             float64
# UpdatedBnchmk                           int64
# HistBnchmk                              int64
# ABtotBnchmk                             int64
# ABtotExp                                int64
# Adv_Pay_Amt                           float64
# Adv_Pay_Recoup                        float64
# QualPerfShare                         float64
# FinalShareRate                        float64
# Per_Capita_Exp_ALL_ESRD_BY1             int64
# Per_Capita_Exp_ALL_DIS_BY1              int64
# Per_Capita_Exp_ALL_AGDU_BY1             int64
# Per_Capita_Exp_ALL_AGND_BY1             int64
# Per_Capita_Exp_ALL_ESRD_BY2             int64
# Per_Capita_Exp_ALL_DIS_BY2              int64
# Per_Capita_Exp_ALL_AGDU_BY2             int64
# Per_Capita_Exp_ALL_AGND_BY2             int64
# Per_Capita_Exp_ALL_ESRD_BY3             int64
# Per_Capita_Exp_ALL_DIS_BY3              int64
# Per_Capita_Exp_ALL_AGDU_BY3             int64
# Per_Capita_Exp_ALL_AGND_BY3             int64
# Per_Capita_Exp_ALL_ESRD_PY              int64
# Per_Capita_Exp_ALL_DIS_PY               int64
# Per_Capita_Exp_ALL_AGDU_PY              int64
# Per_Capita_Exp_ALL_AGND_PY              int64
# Per_Capita_Exp_TOTAL_PY                 int64
# CMS_HCC_RiskScore_ESRD_BY1            float64
# CMS_HCC_RiskScore_DIS_BY1             float64
# CMS_HCC_RiskScore_AGDU_BY1            float64
# CMS_HCC_RiskScore_AGND_BY1            float64
# CMS_HCC_RiskScore_ESRD_BY2            float64
# CMS_HCC_RiskScore_DIS_BY2             float64
# CMS_HCC_RiskScore_AGDU_BY2            float64
# CMS_HCC_RiskScore_AGND_BY2            float64
# CMS_HCC_RiskScore_ESRD_BY3            float64
# CMS_HCC_RiskScore_DIS_BY3             float64
# CMS_HCC_RiskScore_AGDU_BY3            float64
# CMS_HCC_RiskScore_AGND_BY3            float64
# CMS_HCC_RiskScore_ESRD_PY             float64
# CMS_HCC_RiskScore_DIS_PY              float64
# CMS_HCC_RiskScore_AGDU_PY             float64
# CMS_HCC_RiskScore_AGND_PY             float64
# N_AB_Year_ESRD_BY3                    float64
# N_AB_Year_DIS_BY3                     float64
# N_AB_Year_AGED_Dual_BY3               float64
# N_AB_Year_AGED_NonDual_BY3            float64
# N_AB_Year_PY                          float64
# N_AB_Year_ESRD_PY                     float64
# N_AB_Year_DIS_PY                      float64
# N_AB_Year_AGED_Dual_PY                float64
# N_AB_Year_AGED_NonDual_PY             float64
# N_Ben_Age_0_64                          int64
# N_Ben_Age_65_74                         int64
# N_Ben_Age_75_84                         int64
# N_Ben_Age_85plus                        int64
# N_Ben_Female                            int64
# N_Ben_Male                              int64
# N_Ben_Race_White                        int64
# N_Ben_Race_Black                        int64
# N_Ben_Race_Asian                        int64
# N_Ben_Race_Hisp                         int64
# N_Ben_Race_Native                       int64
# N_Ben_Race_Other                        int64
# CapAnn_INP_All                          int64
# CapAnn_INP_S_trm                        int64
# CapAnn_INP_L_trm                        int64
# CapAnn_INP_Rehab                        int64
# CapAnn_INP_Psych                        int64
# CapAnn_HSP                              int64
# CapAnn_SNF                              int64
# CapAnn_INP_Other                        int64
# CapAnn_OPD                              int64
# CapAnn_PB                               int64
# CapAnn_AmbPay                           int64
# CapAnn_HHA                              int64
# CapAnn_DME                              int64
# ADM                                   float64
# ADM_S_Trm                             float64
# ADM_L_Trm                             float64
# ADM_Rehab                             float64
# ADM_Psych                             float64
# CHF_ADM                               float64
# COPD_ADM                              float64
# PNEU_ADM                              float64
# readm_Rate_1000                       float64
# prov_Rate_1000                        float64
# P_SNF_ADM                             float64
# P_EDV_Vis                             float64
# P_EDV_Vis_HOSP                        float64
# P_CT_VIS                              float64
# P_MRI_VIS                             float64
# P_EM_Total                            float64
# P_EM_PCP_Vis                          float64
# P_EM_SP_Vis                           float64
# P_Nurse_Vis                           float64
# P_FQHC_RHC_Vis                        float64
# N_CAH                                   int64
# N_FQHC                                  int64
# N_RHC                                   int64
# N_ETA                                   int64
# N_Fac_Other                             int64
# N_PCP                                   int64
# N_Spec                                  int64
# N_NP                                    int64
# N_PA                                    int64
# N_CNS                                   int64
# dtype: object

# %%
df13 = create_df(2013)

change_to_date(df13, 'Start_Date')
remove_commas(df13, 'BnchmkMinExp')
change_to_num(df13, 'BnchmkMinExp')

df13.dtypes
# Out:
# ACO_NAME                              object
# Start_Date                    datetime64[ns]
# Track2                                 int64
# Adv_Pay                                int64
# Int_Pmt                              float64
# Adv_Pay_Amt                          float64
# QualScore                              int64
# QualPerfShare                        float64
# FinalShareRate                       float64
# MinLossPerc                          float64
# MinSavPerc                           float64
# ABtotBnchmk                          float64
# ABtotExp                             float64
# BnchmkMinExp                         float64
# EarnShrSavings                       float64
# OweLosses                            float64
# N_AB                                   int64
# N_AB_Year                            float64
# N_AB_Year_ESRD                       float64
# N_AB_Year_DIS                        float64
# N_AB_Year_AGED_Dual                  float64
# N_AB_Year_AGED_NonDual               float64
# N_Ben_Age_0_64                         int64
# N_Ben_Age_65_74                        int64
# N_Ben_Age_75_84                        int64
# N_Ben_Age_85plus                       int64
# N_Ben_Female                           int64
# N_Ben_Male                             int64
# N_Ben_Race_White                       int64
# N_Ben_Race_Black                       int64
# N_Ben_Race_Asian                       int64
# N_Ben_Race_Hisp                        int64
# N_Ben_Race_Native                      int64
# N_Ben_Race_Other                       int64
# Per_Capita_Exp_ALL_ESRD              float64
# Per_Capita_Exp_ALL_DIS               float64
# Per_Capita_Exp_ALL_AGDU              float64
# Per_Capita_Exp_ALL_AGND              float64
# CapAnn_INP_All                       float64
# CapAnn_INP_S_trm                     float64
# CapAnn_INP_L_trm                     float64
# CapAnn_INP_Rehab                     float64
# CapAnn_INP_Psych                     float64
# CapAnn_HSP                           float64
# CapAnn_SNF                           float64
# CapAnn_INP_Other                     float64
# CapAnn_PB                            float64
# CapAnn_AmbPay                        float64
# CapAnn_HHA                           float64
# CapAnn_DME                           float64
# ADM                                  float64
# ADM_S_Trm                            float64
# ADM_L_Trm                            float64
# ADM_Rehab                            float64
# ADM_Psych                            float64
# chf_adm                              float64
# copd_adm                             float64
# pneu_adm                             float64
# readm_Rate_1000                      float64
# prov_Rate_1000                       float64
# P_SNF_ADM                            float64
# P_EDV_Vis                            float64
# P_EDV_Vis_HOSP                       float64
# P_CT_VIS                             float64
# P_MRI_VIS                            float64
# P_EM_Total                           float64
# P_EM_PCP_Vis                         float64
# P_EM_SP_Vis                          float64
# P_Nurse_Vis                          float64
# P_FQHC_RHC_Vis                       float64
# N_CAH                                  int64
# N_FQHC                                 int64
# N_RHC                                  int64
# N_ETA                                  int64
# N_Fac_Other                            int64
# N_PCP                                  int64
# N_Spec                                 int64
# N_NP                                   int64
# N_PA                                   int64
# N_CNS                                  int64
# CMS_HCC_RiskScore_ESRD_BY1           float64
# CMS_HCC_RiskScore_DIS_BY1            float64
# CMS_HCC_RiskScore_AGDU_BY1           float64
# CMS_HCC_RiskScore_AGND_BY1           float64
# CMS_HCC_RiskScore_ESRD_BY2           float64
# CMS_HCC_RiskScore_DIS_BY2            float64
# CMS_HCC_RiskScore_AGDU_BY2           float64
# CMS_HCC_RiskScore_AGND_BY2           float64
# CMS_HCC_RiskScore_ESRD_BY3           float64
# CMS_HCC_RiskScore_DIS_BY3            float64
# CMS_HCC_RiskScore_AGDU_BY3           float64
# CMS_HCC_RiskScore_AGND_BY3           float64
# CMS_HCC_RiskScore_ESRD_PY            float64
# CMS_HCC_RiskScore_DIS_PY             float64
# CMS_HCC_RiskScore_AGDU_PY            float64
# CMS_HCC_RiskScore_AGND_PY            float64
# dtype: object
